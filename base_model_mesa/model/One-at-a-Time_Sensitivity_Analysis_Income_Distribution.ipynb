# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sensitivity_analysis_path = r'../output_data/SensitivityAnalysisIncomeDistribution.csv'
sensitivity_analysis = pd.read_csv(sensitivity_analysis_path)
columns_to_drop = ['AverageDamagePerIncomeLabel', 'EstimatedAverageDamagePerIncomeLabel', 'AverageIncomeToDamageRatio', 'EstimatedAverageIncomeToDamageRatio']
sensitivity_analysis.drop(columns = columns_to_drop, inplace = True)
sensitivity_analysis
# Out:
#        RunId  iteration  Step  number_of_households  number_of_steps  \
# 0          0          0     0                  1000               80
# 1          0          0     1                  1000               80
# 2          0          0     2                  1000               80
# 3          0          0     3                  1000               80
# 4          0          0     4                  1000               80
# ...      ...        ...   ...                   ...              ...
# 19697    499         99    12                  1000               80
# 19698    499         99    13                  1000               80
# 19699    499         99    14                  1000               80
# 19700    499         99    15                  1000               80
# 19701    499         99    16                  1000               80
#
#       flood_map_choice         network  \
# 0                100yr  watts_strogatz
# 1                100yr  watts_strogatz
# ...

# %% [markdown]
# First, we divide all the dataframe based on the income distribution that has been chosen for that model run. This way, we can analyse easier seperately. The different income distributions are here:
#
#  income_distribution_base = {'Poor': [5000, 1875], 'Middle-Class': [29375, 10312], 'Rich': [87500, 18750]},
#  income_distribution_plus_10 = {'Poor': [5500, 1875], 'Middle-Class': [32312.5, 10321], 'Rich': [96250, 18750]}
#  income_distribution_minus_10 = {'Poor': [4500, 1875], 'Middle-Class': [26437.5, 10321], 'Rich': [78750, 18750]}
#  income_distribution_plus_30 = {'Poor': [6500, 1875], 'Middle-Class': [38187.5, 10321], 'Rich': [133750, 18750]}
#  income_distribution_minus_30 = {'Poor': [3500, 1875], 'Middle-Class': [20562.5, 10321], 'Rich': [61250, 18750]}
#
# With this, we can analyse the different behaviours in the models depending on different income distribution, ran one at a time.

# %%
income_distribution_base = pd.DataFrame()

base = str({'Poor': [5000, 1875], 'Middle-Class': [29375, 10312], 'Rich': [87500, 18750]})

condition = sensitivity_analysis['income_distribution'] == base

income_distribution_base_df = pd.concat([sensitivity_analysis[condition], income_distribution_base], ignore_index=True)

#income_distribution_base_df

# %%
income_distribution_plus_10 = pd.DataFrame()

plus_10 = str({'Poor': [5500, 1875], 'Middle-Class': [32312.5, 10321], 'Rich': [96250, 18750]})

condition = sensitivity_analysis['income_distribution'] == plus_10

income_distribution_plus_10_df = pd.concat([sensitivity_analysis[condition], income_distribution_plus_10], ignore_index=True)

#income_distribution_plus_10_df

# %%
income_distribution_minus_10 = pd.DataFrame()

minus_10 = str({'Poor': [4500, 1875], 'Middle-Class': [26437.5, 10321], 'Rich': [78750, 18750]})

condition = sensitivity_analysis['income_distribution'] == minus_10

income_distribution_minus_10_df = pd.concat([sensitivity_analysis[condition], income_distribution_minus_10], ignore_index=True)

#income_distribution_minus_10_df

# %%
income_distribution_plus_30 = pd.DataFrame()

plus_30 = str({'Poor': [6500, 1875], 'Middle-Class': [38187.5, 10321], 'Rich': [133750, 18750]})

condition = sensitivity_analysis['income_distribution'] == plus_30

income_distribution_plus_30_df = pd.concat([sensitivity_analysis[condition], income_distribution_plus_30], ignore_index=True)

#income_distribution_plus_30_df

# %%
income_distribution_minus_30 = pd.DataFrame()

minus_30 = str({'Poor': [3500, 1875], 'Middle-Class': [20562.5, 10321], 'Rich': [61250, 18750]})

condition = sensitivity_analysis['income_distribution'] == minus_30

income_distribution_minus_30_df = pd.concat([sensitivity_analysis[condition], income_distribution_minus_30], ignore_index=True)

income_distribution_minus_30_df
# Out:
#       RunId  iteration  Step  number_of_households  number_of_steps  \
# 0         4          0     0                  1000               80
# 1         4          0     1                  1000               80
# 2         4          0     2                  1000               80
# 3         4          0     3                  1000               80
# 4         4          0     4                  1000               80
# ...     ...        ...   ...                   ...              ...
# 4098    499         99    12                  1000               80
# 4099    499         99    13                  1000               80
# 4100    499         99    14                  1000               80
# 4101    499         99    15                  1000               80
# 4102    499         99    16                  1000               80
#
#      flood_map_choice         network  \
# 0               100yr  watts_strogatz
# 1               100yr  watts_strogatz
# ...

# %% [markdown]
# # Poor households

# %%
#First, poor households get isolated
estimated_ratio_base = income_distribution_base_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamagePoorHousehold']]
estimated_ratio_plus_10 = income_distribution_plus_10_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamagePoorHousehold']]
estimated_ratio_minus_10 = income_distribution_minus_10_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamagePoorHousehold']]
estimated_ratio_plus_30 = income_distribution_plus_30_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamagePoorHousehold']]
estimated_ratio_minus_30 = income_distribution_minus_30_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamagePoorHousehold']]

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Assuming 'estimated_ratio_base' is your DataFrame with columns 'RunId', 'Step', and 'EstimatedAverageIncomeToDamagePoorHousehold'
# Assuming 'estimated_ratio_plus_10' is another DataFrame with the same structure
# Assuming 'estimated_ratio_minus_10' is another DataFrame with the same structure
# Assuming 'estimated_ratio_plus_30' is another DataFrame with the same structure
# Assuming 'estimated_ratio_minus_30' is another DataFrame with the same structure

# Calculate the mean and standard deviation for each step in the first DataFrame
mean_values_base = estimated_ratio_base.groupby('Step')['EstimatedAverageIncomeToDamagePoorHousehold'].mean()
std_values_base = estimated_ratio_base.groupby('Step')['EstimatedAverageIncomeToDamagePoorHousehold'].std()

# Calculate the mean and standard deviation for each step in the second DataFrame
mean_values_plus_10 = estimated_ratio_plus_10.groupby('Step')['EstimatedAverageIncomeToDamagePoorHousehold'].mean()
std_values_plus_10 = estimated_ratio_plus_10.groupby('Step')['EstimatedAverageIncomeToDamagePoorHousehold'].std()

# Calculate the mean and standard deviation for each step in the third DataFrame
mean_values_minus_10 = estimated_ratio_minus_10.groupby('Step')['EstimatedAverageIncomeToDamagePoorHousehold'].mean()
std_values_minus_10 = estimated_ratio_minus_10.groupby('Step')['EstimatedAverageIncomeToDamagePoorHousehold'].std()

# Calculate the mean and standard deviation for each step in the fourth DataFrame
mean_values_plus_30 = estimated_ratio_plus_30.groupby('Step')['EstimatedAverageIncomeToDamagePoorHousehold'].mean()
std_values_plus_30 = estimated_ratio_plus_30.groupby('Step')['EstimatedAverageIncomeToDamagePoorHousehold'].std()

# Calculate the mean and standard deviation for each step in the fifth DataFrame
mean_values_minus_30 = estimated_ratio_minus_30.groupby('Step')['EstimatedAverageIncomeToDamagePoorHousehold'].mean()
std_values_minus_30 = estimated_ratio_minus_30.groupby('Step')['EstimatedAverageIncomeToDamagePoorHousehold'].std()

# Plot the mean line for the first DataFrame
ax.plot(mean_values_base.index, mean_values_base, label='Mean (Base)')

# Fill between the upper and lower bounds for the first DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_base.index, mean_values_base - std_values_base, mean_values_base + std_values_base, alpha=0.2, label='Variability (Base)')

# Plot the mean line for the second DataFrame
ax.plot(mean_values_plus_10.index, mean_values_plus_10, label='Mean (Plus 10)')

# Fill between the upper and lower bounds for the second DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_10.index, mean_values_plus_10 - std_values_plus_10, mean_values_plus_10 + std_values_plus_10, alpha=0.2, label='Variability (Plus 10)')

# Plot the mean line for the third DataFrame
ax.plot(mean_values_minus_10.index, mean_values_minus_10, label='Mean (Minus 10)')

# Fill between the upper and lower bounds for the third DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_10.index, mean_values_minus_10 - std_values_minus_10, mean_values_minus_10 + std_values_minus_10, alpha=0.2, label='Variability (Minus 10)')

# Plot the mean line for the fourth DataFrame
ax.plot(mean_values_plus_30.index, mean_values_plus_30, label='Mean (Plus 30)')

# Fill between the upper and lower bounds for the fourth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_30.index, mean_values_plus_30 - std_values_plus_30, mean_values_plus_30 + std_values_plus_30, alpha=0.2, label='Variability (Plus 30)')

# Plot the mean line for the fifth DataFrame
ax.plot(mean_values_minus_30.index, mean_values_minus_30, label='Mean (Minus 30)')

# Fill between the upper and lower bounds for the fifth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_30.index, mean_values_minus_30 - std_values_minus_30, mean_values_minus_30 + std_values_minus_30, alpha=0.2, label='Variability (Minus 30)')

# Customize labels and title
ax.set_xlabel('Step')
ax.set_ylabel('EstimatedAverageIncomeToDamagePoorHousehold')
ax.set_title('Estimated Average Income To Damage for Poor Households with five different income distributions as input')

# Show legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# Now, let us look at the average damage for poor households and see if there is a difference

# %%
estimated_average_base = income_distribution_base_df[['RunId', 'Step', 'EstimatedAverageDamagePerPoorHousehold']]
estimated_average_plus_10 = income_distribution_plus_10_df[['RunId', 'Step', 'EstimatedAverageDamagePerPoorHousehold']]
estimated_average_minus_10 = income_distribution_minus_10_df[['RunId', 'Step', 'EstimatedAverageDamagePerPoorHousehold']]
estimated_average_plus_30 = income_distribution_plus_30_df[['RunId', 'Step', 'EstimatedAverageDamagePerPoorHousehold']]
estimated_average_minus_30 = income_distribution_minus_30_df[['RunId', 'Step', 'EstimatedAverageDamagePerPoorHousehold']]

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Assuming 'estimated_ratio_base' is your DataFrame with columns 'RunId', 'Step', and 'EstimatedAverageDamagePerPoorHousehold'
# Assuming 'estimated_ratio_plus_10' is another DataFrame with the same structure
# Assuming 'estimated_ratio_minus_10' is another DataFrame with the same structure
# Assuming 'estimated_ratio_plus_30' is another DataFrame with the same structure
# Assuming 'estimated_ratio_minus_30' is another DataFrame with the same structure

# Calculate the mean and standard deviation for each step in the first DataFrame
mean_values_base = estimated_average_base.groupby('Step')['EstimatedAverageDamagePerPoorHousehold'].mean()
std_values_base = estimated_average_base.groupby('Step')['EstimatedAverageDamagePerPoorHousehold'].std()

# Calculate the mean and standard deviation for each step in the second DataFrame
mean_values_plus_10 = estimated_average_plus_10.groupby('Step')['EstimatedAverageDamagePerPoorHousehold'].mean()
std_values_plus_10 = estimated_average_plus_10.groupby('Step')['EstimatedAverageDamagePerPoorHousehold'].std()

# Calculate the mean and standard deviation for each step in the third DataFrame
mean_values_minus_10 = estimated_average_minus_10.groupby('Step')['EstimatedAverageDamagePerPoorHousehold'].mean()
std_values_minus_10 = estimated_average_minus_10.groupby('Step')['EstimatedAverageDamagePerPoorHousehold'].std()

# Calculate the mean and standard deviation for each step in the fourth DataFrame
mean_values_plus_30 = estimated_average_plus_30.groupby('Step')['EstimatedAverageDamagePerPoorHousehold'].mean()
std_values_plus_30 = estimated_average_plus_30.groupby('Step')['EstimatedAverageDamagePerPoorHousehold'].std()

# Calculate the mean and standard deviation for each step in the fifth DataFrame
mean_values_minus_30 = estimated_average_minus_30.groupby('Step')['EstimatedAverageDamagePerPoorHousehold'].mean()
std_values_minus_30 = estimated_average_minus_30.groupby('Step')['EstimatedAverageDamagePerPoorHousehold'].std()

# Plot the mean line for the first DataFrame
ax.plot(mean_values_base.index, mean_values_base, label='Mean (Base)')

# Fill between the upper and lower bounds for the first DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_base.index, mean_values_base - std_values_base, mean_values_base + std_values_base, alpha=0.2, label='Variability (Base)')

# Plot the mean line for the second DataFrame
ax.plot(mean_values_plus_10.index, mean_values_plus_10, label='Mean (Plus 10)')

# Fill between the upper and lower bounds for the second DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_10.index, mean_values_plus_10 - std_values_plus_10, mean_values_plus_10 + std_values_plus_10, alpha=0.2, label='Variability (Plus 10)')

# Plot the mean line for the third DataFrame
ax.plot(mean_values_minus_10.index, mean_values_minus_10, label='Mean (Minus 10)')

# Fill between the upper and lower bounds for the third DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_10.index, mean_values_minus_10 - std_values_minus_10, mean_values_minus_10 + std_values_minus_10, alpha=0.2, label='Variability (Minus 10)')

# Plot the mean line for the fourth DataFrame
ax.plot(mean_values_plus_30.index, mean_values_plus_30, label='Mean (Plus 30)')

# Fill between the upper and lower bounds for the fourth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_30.index, mean_values_plus_30 - std_values_plus_30, mean_values_plus_30 + std_values_plus_30, alpha=0.2, label='Variability (Plus 30)')

# Plot the mean line for the fifth DataFrame
ax.plot(mean_values_minus_30.index, mean_values_minus_30, label='Mean (Minus 30)')

# Fill between the upper and lower bounds for the fifth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_30.index, mean_values_minus_30 - std_values_minus_30, mean_values_minus_30 + std_values_minus_30, alpha=0.2, label='Variability (Minus 30)')

# Customize labels and title
ax.set_xlabel('Step')
ax.set_ylabel('EstimatedAverageDamagePerPoorHousehold')
ax.set_title('Estimated Average Damage Per Poor Household with five income distribution inputs')

# Show legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# # Middle-Class

# %%
estimated_ratio_base = income_distribution_base_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamageMiddleClassHousehold']]
estimated_ratio_plus_10 = income_distribution_plus_10_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamageMiddleClassHousehold']]
estimated_ratio_minus_10 = income_distribution_minus_10_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamageMiddleClassHousehold']]
estimtaed_ratio_plus_30 = income_distribution_plus_30_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamageMiddleClassHousehold']]
estimated_ratio_minus_30 = income_distribution_minus_30_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamageMiddleClassHousehold']]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))

# Assuming 'estimated_ratio_base' is your DataFrame with columns 'RunId', 'Step', and 'EstimatedAverageIncomeToDamageMiddleClassHousehold'
# Assuming 'estimated_ratio_plus_10' is another DataFrame with the same structure
# Assuming 'estimated_ratio_minus_10' is another DataFrame with the same structure
# Assuming 'estimtaed_ratio_plus_30' is another DataFrame with the same structure
# Assuming 'estimated_ratio_minus_30' is another DataFrame with the same structure

# Calculate the mean and standard deviation for each step in the first DataFrame
mean_values_base = estimated_ratio_base.groupby('Step')['EstimatedAverageIncomeToDamageMiddleClassHousehold'].mean()
std_values_base = estimated_ratio_base.groupby('Step')['EstimatedAverageIncomeToDamageMiddleClassHousehold'].std()

# Calculate the mean and standard deviation for each step in the second DataFrame
mean_values_plus_10 = estimated_ratio_plus_10.groupby('Step')['EstimatedAverageIncomeToDamageMiddleClassHousehold'].mean()
std_values_plus_10 = estimated_ratio_plus_10.groupby('Step')['EstimatedAverageIncomeToDamageMiddleClassHousehold'].std()

# Calculate the mean and standard deviation for each step in the third DataFrame
mean_values_minus_10 = estimated_ratio_minus_10.groupby('Step')['EstimatedAverageIncomeToDamageMiddleClassHousehold'].mean()
std_values_minus_10 = estimated_ratio_minus_10.groupby('Step')['EstimatedAverageIncomeToDamageMiddleClassHousehold'].std()

# Calculate the mean and standard deviation for each step in the fourth DataFrame
mean_values_plus_30 = estimtaed_ratio_plus_30.groupby('Step')['EstimatedAverageIncomeToDamageMiddleClassHousehold'].mean()
std_values_plus_30 = estimtaed_ratio_plus_30.groupby('Step')['EstimatedAverageIncomeToDamageMiddleClassHousehold'].std()

# Calculate the mean and standard deviation for each step in the fifth DataFrame
mean_values_minus_30 = estimated_ratio_minus_30.groupby('Step')['EstimatedAverageIncomeToDamageMiddleClassHousehold'].mean()
std_values_minus_30 = estimated_ratio_minus_30.groupby('Step')['EstimatedAverageIncomeToDamageMiddleClassHousehold'].std()

# Plot the mean line for the first DataFrame
ax.plot(mean_values_base.index, mean_values_base, label='Mean (Base)')

# Fill between the upper and lower bounds for the first DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_base.index, mean_values_base - std_values_base, mean_values_base + std_values_base, alpha=0.2, label='Variability (Base)')

# Plot the mean line for the second DataFrame
ax.plot(mean_values_plus_10.index, mean_values_plus_10, label='Mean (Plus 10)')

# Fill between the upper and lower bounds for the second DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_10.index, mean_values_plus_10 - std_values_plus_10, mean_values_plus_10 + std_values_plus_10, alpha=0.2, label='Variability (Plus 10)')

# Plot the mean line for the third DataFrame
ax.plot(mean_values_minus_10.index, mean_values_minus_10, label='Mean (Minus 10)')

# Fill between the upper and lower bounds for the third DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_10.index, mean_values_minus_10 - std_values_minus_10, mean_values_minus_10 + std_values_minus_10, alpha=0.2, label='Variability (Minus 10)')

# Plot the mean line for the fourth DataFrame
ax.plot(mean_values_plus_30.index, mean_values_plus_30, label='Mean (Plus 30)')

# Fill between the upper and lower bounds for the fourth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_30.index, mean_values_plus_30 - std_values_plus_30, mean_values_plus_30 + std_values_plus_30, alpha=0.2, label='Variability (Plus 30)')

# Plot the mean line for the fifth DataFrame
ax.plot(mean_values_minus_30.index, mean_values_minus_30, label='Mean (Minus 30)')

# Fill between the upper and lower bounds for the fifth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_30.index, mean_values_minus_30 - std_values_minus_30, mean_values_minus_30 + std_values_minus_30, alpha=0.2, label='Variability (Minus 30)')

# Customize labels and title
ax.set_xlabel('Step')
ax.set_ylabel('EstimatedAverageIncomeToDamageMiddleClassHousehold')
ax.set_title('Estimated Average Income To Damage for Middle Class Households with five different income distributions as input')

# Show legend
ax.legend()

# Display the plot
plt.show()

# %%
estimated_average_base = income_distribution_base_df[['RunId', 'Step', 'EstimatedAverageDamagePerMiddleClassHousehold']]
estimated_average_plus_10 = income_distribution_plus_10_df[['RunId', 'Step', 'EstimatedAverageDamagePerMiddleClassHousehold']]
estimated_average_minus_10 = income_distribution_minus_10_df[['RunId', 'Step', 'EstimatedAverageDamagePerMiddleClassHousehold']]
estimated_average_plus_30 = income_distribution_plus_30_df[['RunId', 'Step', 'EstimatedAverageDamagePerMiddleClassHousehold']]
estimated_average_minus_30 = income_distribution_minus_30_df[['RunId', 'Step', 'EstimatedAverageDamagePerMiddleClassHousehold']]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))

# Assuming 'estimated_average_base' is your DataFrame with columns 'RunId', 'Step', and 'EstimatedAverageDamagePerMiddleClassHousehold'
# Assuming 'estimated_average_plus_10' is another DataFrame with the same structure
# Assuming 'estimated_average_minus_10' is another DataFrame with the same structure
# Assuming 'estimated_average_plus_30' is another DataFrame with the same structure
# Assuming 'estimated_average_minus_30' is another DataFrame with the same structure

# Calculate the mean and standard deviation for each step in the first DataFrame
mean_values_base = estimated_average_base.groupby('Step')['EstimatedAverageDamagePerMiddleClassHousehold'].mean()
std_values_base = estimated_average_base.groupby('Step')['EstimatedAverageDamagePerMiddleClassHousehold'].std()

# Calculate the mean and standard deviation for each step in the second DataFrame
mean_values_plus_10 = estimated_average_plus_10.groupby('Step')['EstimatedAverageDamagePerMiddleClassHousehold'].mean()
std_values_plus_10 = estimated_average_plus_10.groupby('Step')['EstimatedAverageDamagePerMiddleClassHousehold'].std()

# Calculate the mean and standard deviation for each step in the third DataFrame
mean_values_minus_10 = estimated_average_minus_10.groupby('Step')['EstimatedAverageDamagePerMiddleClassHousehold'].mean()
std_values_minus_10 = estimated_average_minus_10.groupby('Step')['EstimatedAverageDamagePerMiddleClassHousehold'].std()

# Calculate the mean and standard deviation for each step in the fourth DataFrame
mean_values_plus_30 = estimated_average_plus_30.groupby('Step')['EstimatedAverageDamagePerMiddleClassHousehold'].mean()
std_values_plus_30 = estimated_average_plus_30.groupby('Step')['EstimatedAverageDamagePerMiddleClassHousehold'].std()

# Calculate the mean and standard deviation for each step in the fifth DataFrame
mean_values_minus_30 = estimated_average_minus_30.groupby('Step')['EstimatedAverageDamagePerMiddleClassHousehold'].mean()
std_values_minus_30 = estimated_average_minus_30.groupby('Step')['EstimatedAverageDamagePerMiddleClassHousehold'].std()

# Plot the mean line for the first DataFrame
ax.plot(mean_values_base.index, mean_values_base, label='Mean (Base)')

# Fill between the upper and lower bounds for the first DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_base.index, mean_values_base - std_values_base, mean_values_base + std_values_base, alpha=0.2, label='Variability (Base)')

# Plot the mean line for the second DataFrame
ax.plot(mean_values_plus_10.index, mean_values_plus_10, label='Mean (Plus 10)')

# Fill between the upper and lower bounds for the second DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_10.index, mean_values_plus_10 - std_values_plus_10, mean_values_plus_10 + std_values_plus_10, alpha=0.2, label='Variability (Plus 10)')

# Plot the mean line for the third DataFrame
ax.plot(mean_values_minus_10.index, mean_values_minus_10, label='Mean (Minus 10)')

# Fill between the upper and lower bounds for the third DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_10.index, mean_values_minus_10 - std_values_minus_10, mean_values_minus_10 + std_values_minus_10, alpha=0.2, label='Variability (Minus 10)')

# Plot the mean line for the fourth DataFrame
ax.plot(mean_values_plus_30.index, mean_values_plus_30, label='Mean (Plus 30)')

# Fill between the upper and lower bounds for the fourth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_30.index, mean_values_plus_30 - std_values_plus_30, mean_values_plus_30 + std_values_plus_30, alpha=0.2, label='Variability (Plus 30)')

# Plot the mean line for the fifth DataFrame
ax.plot(mean_values_minus_30.index, mean_values_minus_30, label='Mean (Minus 30)')

# Fill between the upper and lower bounds for the fifth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_30.index, mean_values_minus_30 - std_values_minus_30, mean_values_minus_30 + std_values_minus_30, alpha=0.2, label='Variability (Minus 30)')

# Customize labels and title
ax.set_xlabel('Step')
ax.set_ylabel('EstimatedAverageDamagePerMiddleClassHousehold')
ax.set_title('Estimated Average Damage Per MiddleClass Household with five income distribution inputs')

# Show legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# # Rich

# %%
estimated_ratio_base = income_distribution_base_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamageRichHousehold']]
estimated_ratio_plus_10 = income_distribution_plus_10_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamageRichHousehold']]
estimated_ratio_minus_10 = income_distribution_minus_10_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamageRichHousehold']]
estimtaed_ratio_plus_30 = income_distribution_plus_30_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamageRichHousehold']]
estimated_ratio_minus_30 = income_distribution_minus_30_df[['RunId', 'Step', 'EstimatedAverageIncomeToDamageRichHousehold']]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))

# Assuming 'estimated_ratio_base' is your DataFrame with columns 'RunId', 'Step', and 'EstimatedAverageIncomeToDamageRichHousehold'
# Assuming 'estimated_ratio_plus_10' is another DataFrame with the same structure
# Assuming 'estimated_ratio_minus_10' is another DataFrame with the same structure
# Assuming 'estimtaed_ratio_plus_30' is another DataFrame with the same structure
# Assuming 'estimated_ratio_minus_30' is another DataFrame with the same structure

# Calculate the mean and standard deviation for each step in the first DataFrame
mean_values_base = estimated_ratio_base.groupby('Step')['EstimatedAverageIncomeToDamageRichHousehold'].mean()
std_values_base = estimated_ratio_base.groupby('Step')['EstimatedAverageIncomeToDamageRichHousehold'].std()

# Calculate the mean and standard deviation for each step in the second DataFrame
mean_values_plus_10 = estimated_ratio_plus_10.groupby('Step')['EstimatedAverageIncomeToDamageRichHousehold'].mean()
std_values_plus_10 = estimated_ratio_plus_10.groupby('Step')['EstimatedAverageIncomeToDamageRichHousehold'].std()

# Calculate the mean and standard deviation for each step in the third DataFrame
mean_values_minus_10 = estimated_ratio_minus_10.groupby('Step')['EstimatedAverageIncomeToDamageRichHousehold'].mean()
std_values_minus_10 = estimated_ratio_minus_10.groupby('Step')['EstimatedAverageIncomeToDamageRichHousehold'].std()

# Calculate the mean and standard deviation for each step in the fourth DataFrame
mean_values_plus_30 = estimtaed_ratio_plus_30.groupby('Step')['EstimatedAverageIncomeToDamageRichHousehold'].mean()
std_values_plus_30 = estimtaed_ratio_plus_30.groupby('Step')['EstimatedAverageIncomeToDamageRichHousehold'].std()

# Calculate the mean and standard deviation for each step in the fifth DataFrame
mean_values_minus_30 = estimated_ratio_minus_30.groupby('Step')['EstimatedAverageIncomeToDamageRichHousehold'].mean()
std_values_minus_30 = estimated_ratio_minus_30.groupby('Step')['EstimatedAverageIncomeToDamageRichHousehold'].std()

# Plot the mean line for the first DataFrame
ax.plot(mean_values_base.index, mean_values_base, label='Mean (Base)')

# Fill between the upper and lower bounds for the first DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_base.index, mean_values_base - std_values_base, mean_values_base + std_values_base, alpha=0.2, label='Variability (Base)')

# Plot the mean line for the second DataFrame
ax.plot(mean_values_plus_10.index, mean_values_plus_10, label='Mean (Plus 10)')

# Fill between the upper and lower bounds for the second DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_10.index, mean_values_plus_10 - std_values_plus_10, mean_values_plus_10 + std_values_plus_10, alpha=0.2, label='Variability (Plus 10)')

# Plot the mean line for the third DataFrame
ax.plot(mean_values_minus_10.index, mean_values_minus_10, label='Mean (Minus 10)')

# Fill between the upper and lower bounds for the third DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_10.index, mean_values_minus_10 - std_values_minus_10, mean_values_minus_10 + std_values_minus_10, alpha=0.2, label='Variability (Minus 10)')

# Plot the mean line for the fourth DataFrame
ax.plot(mean_values_plus_30.index, mean_values_plus_30, label='Mean (Plus 30)')

# Fill between the upper and lower bounds for the fourth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_30.index, mean_values_plus_30 - std_values_plus_30, mean_values_plus_30 + std_values_plus_30, alpha=0.2, label='Variability (Plus 30)')

# Plot the mean line for the fifth DataFrame
ax.plot(mean_values_minus_30.index, mean_values_minus_30, label='Mean (Minus 30)')

# Fill between the upper and lower bounds for the fifth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_30.index, mean_values_minus_30 - std_values_minus_30, mean_values_minus_30 + std_values_minus_30, alpha=0.2, label='Variability (Minus 30)')

# Customize labels and title
ax.set_xlabel('Step')
ax.set_ylabel('EstimatedAverageIncomeToDamageRichHousehold')
ax.set_title('Estimated Average Income To Damage for Rich Households with five different income distributions as input')

# Show legend
ax.legend()

# Display the plot
plt.show()

# %%
estimated_average_base = income_distribution_base_df[['RunId', 'Step', 'EstimatedAverageDamagePerRichHousehold']]
estimated_average_plus_10 = income_distribution_plus_10_df[['RunId', 'Step', 'EstimatedAverageDamagePerRichHousehold']]
estimated_average_minus_10 = income_distribution_minus_10_df[['RunId', 'Step', 'EstimatedAverageDamagePerRichHousehold']]
estimated_average_plus_30 = income_distribution_plus_30_df[['RunId', 'Step', 'EstimatedAverageDamagePerRichHousehold']]
estimated_average_minus_30 = income_distribution_minus_30_df[['RunId', 'Step', 'EstimatedAverageDamagePerRichHousehold']]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))

# Assuming 'estimated_average_base' is your DataFrame with columns 'RunId', 'Step', and 'EstimatedAverageDamagePerRichHousehold'
# Assuming 'estimated_average_plus_10' is another DataFrame with the same structure
# Assuming 'estimated_average_minus_10' is another DataFrame with the same structure
# Assuming 'estimated_average_plus_30' is another DataFrame with the same structure
# Assuming 'estimated_average_minus_30' is another DataFrame with the same structure

# Calculate the mean and standard deviation for each step in the first DataFrame
mean_values_base = estimated_average_base.groupby('Step')['EstimatedAverageDamagePerRichHousehold'].mean()
std_values_base = estimated_average_base.groupby('Step')['EstimatedAverageDamagePerRichHousehold'].std()

# Calculate the mean and standard deviation for each step in the second DataFrame
mean_values_plus_10 = estimated_average_plus_10.groupby('Step')['EstimatedAverageDamagePerRichHousehold'].mean()
std_values_plus_10 = estimated_average_plus_10.groupby('Step')['EstimatedAverageDamagePerRichHousehold'].std()

# Calculate the mean and standard deviation for each step in the third DataFrame
mean_values_minus_10 = estimated_average_minus_10.groupby('Step')['EstimatedAverageDamagePerRichHousehold'].mean()
std_values_minus_10 = estimated_average_minus_10.groupby('Step')['EstimatedAverageDamagePerRichHousehold'].std()

# Calculate the mean and standard deviation for each step in the fourth DataFrame
mean_values_plus_30 = estimated_average_plus_30.groupby('Step')['EstimatedAverageDamagePerRichHousehold'].mean()
std_values_plus_30 = estimated_average_plus_30.groupby('Step')['EstimatedAverageDamagePerRichHousehold'].std()

# Calculate the mean and standard deviation for each step in the fifth DataFrame
mean_values_minus_30 = estimated_average_minus_30.groupby('Step')['EstimatedAverageDamagePerRichHousehold'].mean()
std_values_minus_30 = estimated_average_minus_30.groupby('Step')['EstimatedAverageDamagePerRichHousehold'].std()

# Plot the mean line for the first DataFrame
ax.plot(mean_values_base.index, mean_values_base, label='Mean (Base)')

# Fill between the upper and lower bounds for the first DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_base.index, mean_values_base - std_values_base, mean_values_base + std_values_base, alpha=0.2, label='Variability (Base)')

# Plot the mean line for the second DataFrame
ax.plot(mean_values_plus_10.index, mean_values_plus_10, label='Mean (Plus 10)')

# Fill between the upper and lower bounds for the second DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_10.index, mean_values_plus_10 - std_values_plus_10, mean_values_plus_10 + std_values_plus_10, alpha=0.2, label='Variability (Plus 10)')

# Plot the mean line for the third DataFrame
ax.plot(mean_values_minus_10.index, mean_values_minus_10, label='Mean (Minus 10)')

# Fill between the upper and lower bounds for the third DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_10.index, mean_values_minus_10 - std_values_minus_10, mean_values_minus_10 + std_values_minus_10, alpha=0.2, label='Variability (Minus 10)')

# Plot the mean line for the fourth DataFrame
ax.plot(mean_values_plus_30.index, mean_values_plus_30, label='Mean (Plus 30)')

# Fill between the upper and lower bounds for the fourth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_30.index, mean_values_plus_30 - std_values_plus_30, mean_values_plus_30 + std_values_plus_30, alpha=0.2, label='Variability (Plus 30)')

# Plot the mean line for the fifth DataFrame
ax.plot(mean_values_minus_30.index, mean_values_minus_30, label='Mean (Minus 30)')

# Fill between the upper and lower bounds for the fifth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_30.index, mean_values_minus_30 - std_values_minus_30, mean_values_minus_30 + std_values_minus_30, alpha=0.2, label='Variability (Minus 30)')

# Customize labels and title
ax.set_xlabel('Step')
ax.set_ylabel('EstimatedAverageDamagePerRichHousehold')
ax.set_title('Estimated Average Damage Per MiddleClass Household with five income distribution inputs')

# Show legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# Next, we look at the adapted households and see if the income distribution has some influence on that

# %%
adapted_households_base = income_distribution_base_df[['RunId', 'Step', 'TotalAdaptedHouseholds']]
adapted_households_plus_10 = income_distribution_plus_10_df[['RunId', 'Step', 'TotalAdaptedHouseholds']]
adapted_households_minus_10 = income_distribution_minus_10_df[['RunId', 'Step', 'TotalAdaptedHouseholds']]
adapted_households_plus_30 = income_distribution_plus_30_df[['RunId', 'Step', 'TotalAdaptedHouseholds']]
adapted_households_minus_30 = income_distribution_minus_30_df[['RunId', 'Step', 'TotalAdaptedHouseholds']]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))

# Assuming 'adapted_households_base' is your DataFrame with columns 'RunId', 'Step', and 'TotalAdaptedHouseholds'
# Assuming 'adapted_households_plus_10' is another DataFrame with the same structure
# Assuming 'adapted_households_minus_10' is another DataFrame with the same structure
# Assuming 'adapted_households_plus_30' is another DataFrame with the same structure
# Assuming 'adapted_households_minus_30' is another DataFrame with the same structure

# Calculate the mean and standard deviation for each step in the first DataFrame
mean_values_base = adapted_households_base.groupby('Step')['TotalAdaptedHouseholds'].mean()
std_values_base = adapted_households_base.groupby('Step')['TotalAdaptedHouseholds'].std()

# Calculate the mean and standard deviation for each step in the second DataFrame
mean_values_plus_10 = adapted_households_plus_10.groupby('Step')['TotalAdaptedHouseholds'].mean()
std_values_plus_10 = adapted_households_plus_10.groupby('Step')['TotalAdaptedHouseholds'].std()

# Calculate the mean and standard deviation for each step in the third DataFrame
mean_values_minus_10 = adapted_households_minus_10.groupby('Step')['TotalAdaptedHouseholds'].mean()
std_values_minus_10 = adapted_households_minus_10.groupby('Step')['TotalAdaptedHouseholds'].std()

# Calculate the mean and standard deviation for each step in the fourth DataFrame
mean_values_plus_30 = adapted_households_plus_30.groupby('Step')['TotalAdaptedHouseholds'].mean()
std_values_plus_30 = adapted_households_plus_30.groupby('Step')['TotalAdaptedHouseholds'].std()

# Calculate the mean and standard deviation for each step in the fifth DataFrame
mean_values_minus_30 = adapted_households_minus_30.groupby('Step')['TotalAdaptedHouseholds'].mean()
std_values_minus_30 = adapted_households_minus_30.groupby('Step')['TotalAdaptedHouseholds'].std()

# Plot the mean line for the first DataFrame
ax.plot(mean_values_base.index, mean_values_base, label='Mean (Base)')

# Fill between the upper and lower bounds for the first DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_base.index, mean_values_base - std_values_base, mean_values_base + std_values_base, alpha=0.2, label='Variability (Base)')

# Plot the mean line for the second DataFrame
ax.plot(mean_values_plus_10.index, mean_values_plus_10, label='Mean (Plus 10)')

# Fill between the upper and lower bounds for the second DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_10.index, mean_values_plus_10 - std_values_plus_10, mean_values_plus_10 + std_values_plus_10, alpha=0.2, label='Variability (Plus 10)')

# Plot the mean line for the third DataFrame
ax.plot(mean_values_minus_10.index, mean_values_minus_10, label='Mean (Minus 10)')

# Fill between the upper and lower bounds for the third DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_10.index, mean_values_minus_10 - std_values_minus_10, mean_values_minus_10 + std_values_minus_10, alpha=0.2, label='Variability (Minus 10)')

# Plot the mean line for the fourth DataFrame
ax.plot(mean_values_plus_30.index, mean_values_plus_30, label='Mean (Plus 30)')

# Fill between the upper and lower bounds for the fourth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_plus_30.index, mean_values_plus_30 - std_values_plus_30, mean_values_plus_30 + std_values_plus_30, alpha=0.2, label='Variability (Plus 30)')

# Plot the mean line for the fifth DataFrame
ax.plot(mean_values_minus_30.index, mean_values_minus_30, label='Mean (Minus 30)')

# Fill between the upper and lower bounds for the fifth DataFrame (mean ± 1 standard deviation)
ax.fill_between(mean_values_minus_30.index, mean_values_minus_30 - std_values_minus_30, mean_values_minus_30 + std_values_minus_30, alpha=0.2, label='Variability (Minus 30)')

# Customize labels and title
ax.set_xlabel('Step')
ax.set_ylabel('TotalAdaptedHouseholds')
ax.set_title('Total Adapted Households average over time for five different income distributions')

# Show legend
ax.legend()

# Display the plot
plt.show()
